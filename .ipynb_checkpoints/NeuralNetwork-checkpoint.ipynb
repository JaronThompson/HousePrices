# %%
import matplotlib.pyplot as plt

from platform import python_version
from scipy import stats

import numpy as np
import scipy.io as sio
import pandas as pd
import sklearn
import matplotlib

import timeit
from tqdm import tqdm
import random
import os

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torchcontrib.optim import SWA
from torch.optim.swa_utils import AveragedModel, SWALR

# import preprocessing tools 
from sklearn.model_selection import KFold
from sklearn.feature_selection import mutual_info_regression as mi
from sklearn.preprocessing import OrdinalEncoder, MinMaxScaler
from sklearn.metrics import r2_score

# %%
print("python version==%s" % python_version())
print("pandas==%s" % pd.__version__)
print("numpy==%s" % np.__version__)
print("sklearn==%s" % sklearn.__version__)
print("torch==%s" % torch.__version__)
print("matplotlib==%s" % matplotlib.__version__)

plt.rcParams[
    "figure.facecolor"
] = "w"  # force white background on plots when using dark mode in JupyterLab


'''if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')'''
device = torch.device('cpu')
# Out:
# python version==3.7.9
# pandas==1.1.3
# numpy==1.19.2
# sklearn==0.23.2
# torch==1.7.0
# matplotlib==3.3.2

# %%
print(os.listdir('DATA'))

train = pd.read_csv("DATA/train.csv").dropna(axis=1)
test = pd.read_csv("DATA/test.csv")

target = np.array(train['SalePrice'].values, np.float)

train.head()
# Out:
# ['data_description.txt', 'house-prices-advanced-regression-techniques.zip', 'sample_submission.csv', 'test.csv', 'train.csv']
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl  ...             0         0           0        0
# 1       FR2       Gtl  ...             0         0           0        0
# 2    Inside       Gtl  ...             0         0           0        0
# 3    Corner       Gtl  ...           272         0           0        0
# 4       FR2       Gtl  ...             0         0           0        0
#
#   MiscVal  MoSold  YrSold  SaleType  SaleCondition SalePrice
# 0       0       2    2008        WD         Normal    208500
# 1       0       5    2007        WD         Normal    181500
# 2       0       9    2008        WD         Normal    223500
# 3       0       2    2006        WD        Abnorml    140000
# 4       0      12    2008        WD         Normal    250000
#
# [5 rows x 62 columns]

# %%
train.shape
# Out:
# (1460, 62)

# %% [markdown]
# # Preprocessing

# %%
# Neighborhood is an important categorical, nominal feature 
# want to do the ordinal encoding manually 
def OrdinalEncoder(df, features, target='SalePrice'):
    # loop through all categorical features 
    for feature in features:
        neighborhoods = df[feature].values
        prices = []
        # for each feature, determine avg target value
        for neighborhood in np.unique(neighborhoods):
            inds = neighborhood == neighborhoods
            prices.append(np.mean(df.iloc[inds, :][target].values))
        ordinal_labels = np.argsort(prices)
        prices_dict = {neighborhood:i for i, neighborhood in enumerate(np.unique(neighborhoods)[ordinal_labels])}
        # encode categorical features ordinally based on target values 
        encoded_neighborhood = [prices_dict[n] for n in neighborhoods]
        df[feature] = encoded_neighborhood
    return df

# pull out categorical and continuous features 
continuousfeatures = train.describe().columns.values[1:-1] 
categoricalfeatures = [ftr for ftr in train.columns.values[1:-1] if ftr not in continuousfeatures]
features = list(continuousfeatures) + categoricalfeatures

# Assume categorical features are ordinal and encode 
train = OrdinalEncoder(train, categoricalfeatures)

# take decades since 2020 for features that describe the year 
yearfeatures = [f for f in features if 'Year' in f or 'Yr' in f]
train[yearfeatures] = (2020 - train[yearfeatures].values)/ 10

# take square root of features that describe area and divide by max 
areafeatures = [f for f in features if 'SF' in f or 'Area' in f]
train[areafeatures] = train[areafeatures].values**.5 / np.max(train[areafeatures].values**.5, 0)

# set up training data 
X = np.array(train[features].values, np.float)
y = np.array(train['SalePrice'].values, np.float)

# center data 
X = MinMaxScaler((-1, 1)).fit(X).transform(X)

# actually predict centered log_y 
y = np.log(y) - np.mean(np.log(y)) 

# set up a dataframe with features and target variables 
train[features] = X 
train['SalePrice'] = y
X_df = train[features]
y_df = train['SalePrice']

# %% [markdown]
# Create a dataset class for use with pytorch dataloader

# %%
class Dataset(torch.utils.data.Dataset):
    def __init__(self, X_df, y_df):
        # set up dataframe
        self.X_df = X_df
        self.y_df = y_df
        

    def __getitem__(self, index):
        
        # load X 
        features = self.X_df.values[index]
        x = torch.tensor(features, dtype=torch.float32)
        
        # load noisey y 
        target = self.y_df.values[index]
        y = torch.tensor(target, dtype=torch.float32)

        return x, y
        
    def __len__(self):
        # total size of your dataset.
        return len(self.X_df)

# %% [markdown]
# # Define NN model

# %%
class Model(nn.Module):
    
    def __init__(self, in_dim, h_dim, out_dim=1):
        super(Model, self).__init__()
        self.input_size  = in_dim
        self.hidden_size = h_dim
        self.output_size = out_dim
        
        # define first fully connected layer 
        self.fc1 = nn.Linear(self.input_size, self.hidden_size)
        
        # define optional second fully connected layer 
        self.fc2 = nn.Linear(self.hidden_size, self.hidden_size)
        
        # add activation 
        self.activation = nn.ReLU()
        
        # define fully connected hidden layer 
        self.output = nn.Linear(self.hidden_size, self.output_size)    
        
    def forward(self, out):
        out = self.fc1(out)
        out = self.activation(out)
        out = self.fc2(out)
        out = self.activation(out)
        out = self.output(out)
        return out

# %%
def NNtrain(model, trainloader, valloader, optimizer, criterion, num_epochs=500, patience=50, verbose=True, path_to_model='model.ckpt'): 
    # set up scheduler to reduce learning rate 
    min_lr = 1e-5
    set_patience = patience
    scheduler = ReduceLROnPlateau(optimizer=optimizer, min_lr=min_lr, mode='min', patience=0, verbose=True)
    best_val = np.inf
    
    for epoch in range(num_epochs):

        # set up model for training     
        model.train()
        for i, (x, y) in enumerate(trainloader):

            # send data to gpu or cpu RAM 
            # input has dimensions (sequence length, batch size, n inputs)
            x = x.to(device)

            # Forward pass
            output = model(x)
            
            # reshape targets to match output
            y = torch.reshape(y, [y.shape[0], 1])
            y = y.to(device)

            # Compute loss 
            loss = criterion(output, y) 
            # Backward pass
            loss.backward()       
            # Optimizer step
            optimizer.step()                        
            # Reset gradients   
            model.zero_grad() 
            

        # Evaluate validation data at end of each epoch
        valid_predictions = []
        valid_targets = []
        model.eval() 
        with torch.no_grad():
            for i, (x, y) in enumerate(valloader):
                x = x.to(device)

                # Forward pass
                output = model(x)

                # reshape targets to match output
                y = torch.reshape(y, [y.shape[0], 1])
                y = y.to(device)

                # Store predictions and true values 
                valid_predictions += list(output.detach().cpu().numpy())
                valid_targets += list(y.cpu().numpy())

        # Calculate performance statistics on validation data 
        val_rmse = np.linalg.norm(np.array(valid_predictions) - np.array(valid_targets))/len(np.array(valid_targets))

        # learning rate is reduced if val roc doesn't improve 
        scheduler.step(val_rmse)
        
        # Save model if validation performance improved 
        if val_rmse < best_val:
            best_val = val_rmse  
            patience = set_patience
            print("Saving model... Epoch [{}/{}], Best Val RMSE: {:.5f}\n".format(epoch+1, num_epochs, best_val))
            torch.save(model.state_dict(), path_to_model)     
        else:
            # if performance doesn't improve, lose some patience 
            patience -= 1
            if patience == 0:
                print("Epoch [{}/{}], Best Val RMSE: {:.5f}\n".format(epoch+1, num_epochs, best_val))    
                break

    # Load best model from fold (in case last epoch was not best)
    model.load_state_dict(torch.load(path_to_model))
    
    return model, best_val

# %% [markdown]
# # Train model

# %%
# set up training params
num_epochs = 250
n_splits_1 = 24
n_splits_2 = 6

# set up out of fold predictions
oof = np.zeros(len(X_df))

# split data into 10 train+validation and testing data sets
skf1 = KFold(n_splits=n_splits_1, shuffle=True, random_state=123)
skf1.get_n_splits(X_df, y_df)
for trainval_index, test_index in skf1.split(X_df):
    # split the whole dataset into training+validation data and testing sets
    X_trainval, X_test = X_df.iloc[trainval_index], X_df.iloc[test_index]
    X_test = torch.tensor(X_test.values, dtype=torch.float32)
    y_trainval, y_test = y_df.iloc[trainval_index], y_df.iloc[test_index]
    
    skf2 = KFold(n_splits=n_splits_2, shuffle=True, random_state=123)
    skf2.get_n_splits(X_trainval, y_trainval)
    y_pred_test = np.zeros([len(y_test), n_splits_2])
    valid_score = np.zeros(n_splits_2)
    for i, (train_index, val_index) in enumerate(skf2.split(X_trainval)):
        X_train, X_val = X_trainval.iloc[train_index], X_trainval.iloc[val_index]
        y_train, y_val = y_trainval.iloc[train_index], y_trainval.iloc[val_index]
    
        # initialize the data set 
        train_dataset = Dataset(X_train, y_train)                                              
        train_loader = torch.utils.data.DataLoader(dataset=train_dataset, batch_size=32) 
        val_dataset  = Dataset(X_val, y_val)
        val_loader   = torch.utils.data.DataLoader(dataset=val_dataset, batch_size=32)

        # initialize model 
        model = Model(in_dim=len(features), h_dim=32, out_dim=1).to(device)

        # define lr and optimizer 
        optimizer = torch.optim.SGD(model.parameters(), lr=.01)
        criterion = torch.nn.MSELoss()

        ### train nn
        model, best_val = NNtrain(model, train_loader, val_loader, 
                        optimizer, criterion, verbose=True)

        # make predictions 
        y_pred_test[:,i] = model(X_test).detach().cpu().numpy().flatten() 
        valid_score[i] = best_val
    
    # store predictions
    oof[test_index] = np.average(y_pred_test, axis=1, weights=valid_score)
# Out:
# Saving model... Epoch [1/500], Best Val RMSE: 0.02427
#
# Saving model... Epoch [2/500], Best Val RMSE: 0.02236
#
# Saving model... Epoch [3/500], Best Val RMSE: 0.02044
#
# Saving model... Epoch [4/500], Best Val RMSE: 0.01870
#
# Saving model... Epoch [5/500], Best Val RMSE: 0.01732
#
# Saving model... Epoch [6/500], Best Val RMSE: 0.01635
#
# Saving model... Epoch [7/500], Best Val RMSE: 0.01569
#
# Saving model... Epoch [8/500], Best Val RMSE: 0.01522
#
# Saving model... Epoch [9/500], Best Val RMSE: 0.01486
#
# Saving model... Epoch [10/500], Best Val RMSE: 0.01455
#
# Saving model... Epoch [11/500], Best Val RMSE: 0.01429
#
# Saving model... Epoch [12/500], Best Val RMSE: 0.01404
#
# Saving model... Epoch [13/500], Best Val RMSE: 0.01382
#
# Saving model... Epoch [14/500], Best Val RMSE: 0.01361
#
# Saving model... Epoch [15/500], Best Val RMSE: 0.01342
#
# Saving model... Epoch [16/500], Best Val RMSE: 0.01324
#
# Saving model... Epoch [17/500], Best Val RMSE: 0.01307
#
# Saving model... Epoch [18/500], Best Val RMSE: 0.01292
#
# Saving model... Epoch [19/500], Best Val RMSE: 0.01277
#
# Saving model... Epoch [20/500], Best Val RMSE: 0.01264
#
# Saving model... Epoch [21/500], Best Val RMSE: 0.01252
#
# Saving model... Epoch [22/500], Best Val RMSE: 0.01240
#
# Saving model... Epoch [23/500], Best Val RMSE: 0.01229
#
# Saving model... Epoch [24/500], Best Val RMSE: 0.01219
#
# Saving model... Epoch [25/500], Best Val RMSE: 0.01209
#
# Saving model... Epoch [26/500], Best Val RMSE: 0.01200
#
# Saving model... Epoch [27/500], Best Val RMSE: 0.01192
#
# Saving model... Epoch [28/500], Best Val RMSE: 0.01184
#
# Saving model... Epoch [29/500], Best Val RMSE: 0.01177
#
# Saving model... Epoch [30/500], Best Val RMSE: 0.01171
#
# Saving model... Epoch [31/500], Best Val RMSE: 0.01164
#
# Saving model... Epoch [32/500], Best Val RMSE: 0.01158
#
# Saving model... Epoch [33/500], Best Val RMSE: 0.01153
#
# Saving model... Epoch [34/500], Best Val RMSE: 0.01147
#
# Saving model... Epoch [35/500], Best Val RMSE: 0.01142
#
# Saving model... Epoch [36/500], Best Val RMSE: 0.01138
#
# Saving model... Epoch [37/500], Best Val RMSE: 0.01133
#
# Saving model... Epoch [38/500], Best Val RMSE: 0.01129
#
# Saving model... Epoch [39/500], Best Val RMSE: 0.01125
#
# Saving model... Epoch [40/500], Best Val RMSE: 0.01121
#
# Saving model... Epoch [41/500], Best Val RMSE: 0.01118
#
# Saving model... Epoch [42/500], Best Val RMSE: 0.01114
#
# Saving model... Epoch [43/500], Best Val RMSE: 0.01111
#
# Saving model... Epoch [44/500], Best Val RMSE: 0.01108
#
# Saving model... Epoch [45/500], Best Val RMSE: 0.01105
#
# Saving model... Epoch [46/500], Best Val RMSE: 0.01102
#
# Saving model... Epoch [47/500], Best Val RMSE: 0.01099
#
# Saving model... Epoch [48/500], Best Val RMSE: 0.01097
#
# Saving model... Epoch [49/500], Best Val RMSE: 0.01094
#
# Saving model... Epoch [50/500], Best Val RMSE: 0.01092
#
# Saving model... Epoch [51/500], Best Val RMSE: 0.01090
#
# Saving model... Epoch [52/500], Best Val RMSE: 0.01088
#
# Saving model... Epoch [53/500], Best Val RMSE: 0.01086
#
# Saving model... Epoch [54/500], Best Val RMSE: 0.01084
#
# Saving model... Epoch [55/500], Best Val RMSE: 0.01082
#
# Saving model... Epoch [56/500], Best Val RMSE: 0.01080
#
# Saving model... Epoch [57/500], Best Val RMSE: 0.01078
#
# Saving model... Epoch [58/500], Best Val RMSE: 0.01077
#
# Saving model... Epoch [59/500], Best Val RMSE: 0.01075
#
# Saving model... Epoch [60/500], Best Val RMSE: 0.01074
#
# Saving model... Epoch [61/500], Best Val RMSE: 0.01072
#
# Saving model... Epoch [62/500], Best Val RMSE: 0.01071
#
# Saving model... Epoch [63/500], Best Val RMSE: 0.01069
#
# Saving model... Epoch [64/500], Best Val RMSE: 0.01068
#
# Saving model... Epoch [65/500], Best Val RMSE: 0.01067
#
# Saving model... Epoch [66/500], Best Val RMSE: 0.01066
#
# Saving model... Epoch [67/500], Best Val RMSE: 0.01064
#
# Saving model... Epoch [68/500], Best Val RMSE: 0.01063
#
# Saving model... Epoch [69/500], Best Val RMSE: 0.01062
#
# Saving model... Epoch [70/500], Best Val RMSE: 0.01061
#
# Saving model... Epoch [71/500], Best Val RMSE: 0.01060
#
# Saving model... Epoch [72/500], Best Val RMSE: 0.01059
#
# Saving model... Epoch [73/500], Best Val RMSE: 0.01058
#
# Saving model... Epoch [74/500], Best Val RMSE: 0.01057
#
# Saving model... Epoch [75/500], Best Val RMSE: 0.01056
#
# Saving model... Epoch [76/500], Best Val RMSE: 0.01055
#
# Saving model... Epoch [77/500], Best Val RMSE: 0.01054
#
# Saving model... Epoch [78/500], Best Val RMSE: 0.01054
#
# Saving model... Epoch [79/500], Best Val RMSE: 0.01053
#
# Saving model... Epoch [80/500], Best Val RMSE: 0.01052
#
# Saving model... Epoch [81/500], Best Val RMSE: 0.01051
#
# Saving model... Epoch [82/500], Best Val RMSE: 0.01050
#
# Saving model... Epoch [83/500], Best Val RMSE: 0.01049
#
# Saving model... Epoch [84/500], Best Val RMSE: 0.01049
#
# Saving model... Epoch [85/500], Best Val RMSE: 0.01048
#
# Saving model... Epoch [86/500], Best Val RMSE: 0.01047
#
# Saving model... Epoch [87/500], Best Val RMSE: 0.01047
#
# Saving model... Epoch [88/500], Best Val RMSE: 0.01046
#
# Saving model... Epoch [89/500], Best Val RMSE: 0.01045
#
# Saving model... Epoch [90/500], Best Val RMSE: 0.01045
#
# Saving model... Epoch [91/500], Best Val RMSE: 0.01044
#
# Saving model... Epoch [92/500], Best Val RMSE: 0.01043
#
# Saving model... Epoch [93/500], Best Val RMSE: 0.01043
#
# Saving model... Epoch [94/500], Best Val RMSE: 0.01042
#
# Saving model... Epoch [95/500], Best Val RMSE: 0.01042
#
# Saving model... Epoch [96/500], Best Val RMSE: 0.01041
#
# Saving model... Epoch [97/500], Best Val RMSE: 0.01041
#
# Saving model... Epoch [98/500], Best Val RMSE: 0.01040
#
# Saving model... Epoch [99/500], Best Val RMSE: 0.01040
#
# Saving model... Epoch [100/500], Best Val RMSE: 0.01039
#
# Saving model... Epoch [101/500], Best Val RMSE: 0.01039
#
# Saving model... Epoch [102/500], Best Val RMSE: 0.01038
#
# Saving model... Epoch [103/500], Best Val RMSE: 0.01038
#
# Saving model... Epoch [104/500], Best Val RMSE: 0.01037
#
# Saving model... Epoch [105/500], Best Val RMSE: 0.01037
#
# Saving model... Epoch [106/500], Best Val RMSE: 0.01036
#
# Saving model... Epoch [107/500], Best Val RMSE: 0.01036
#
# Saving model... Epoch [108/500], Best Val RMSE: 0.01036
#
# Saving model... Epoch [109/500], Best Val RMSE: 0.01035
#
# Saving model... Epoch [110/500], Best Val RMSE: 0.01035
#
# Saving model... Epoch [111/500], Best Val RMSE: 0.01034
#
# Saving model... Epoch [112/500], Best Val RMSE: 0.01034
#
# Saving model... Epoch [113/500], Best Val RMSE: 0.01034
#
# Saving model... Epoch [114/500], Best Val RMSE: 0.01033
#
# Saving model... Epoch [115/500], Best Val RMSE: 0.01033
#
# Saving model... Epoch [116/500], Best Val RMSE: 0.01033
#
# Saving model... Epoch [117/500], Best Val RMSE: 0.01032
#
# Saving model... Epoch [118/500], Best Val RMSE: 0.01032
#
# Saving model... Epoch [119/500], Best Val RMSE: 0.01032
#
# Saving model... Epoch [120/500], Best Val RMSE: 0.01031
#
# Saving model... Epoch [121/500], Best Val RMSE: 0.01031
#
# Saving model... Epoch [122/500], Best Val RMSE: 0.01031
#
# Saving model... Epoch [123/500], Best Val RMSE: 0.01031
#
# Saving model... Epoch [124/500], Best Val RMSE: 0.01030
#
# Saving model... Epoch [125/500], Best Val RMSE: 0.01030
#
# Saving model... Epoch [126/500], Best Val RMSE: 0.01030
#
# Saving model... Epoch [127/500], Best Val RMSE: 0.01030
#
# Saving model... Epoch [128/500], Best Val RMSE: 0.01029
#
# Saving model... Epoch [129/500], Best Val RMSE: 0.01029
#
# Saving model... Epoch [130/500], Best Val RMSE: 0.01029
#
# Saving model... Epoch [131/500], Best Val RMSE: 0.01029
#
# Saving model... Epoch [132/500], Best Val RMSE: 0.01029
#
# Saving model... Epoch [133/500], Best Val RMSE: 0.01028
#
# Saving model... Epoch [134/500], Best Val RMSE: 0.01028
#
# Saving model... Epoch [135/500], Best Val RMSE: 0.01028
#
# Saving model... Epoch [136/500], Best Val RMSE: 0.01028
#
# Saving model... Epoch [137/500], Best Val RMSE: 0.01028
#
# Saving model... Epoch [138/500], Best Val RMSE: 0.01027
#
# Saving model... Epoch [139/500], Best Val RMSE: 0.01027
#
# Saving model... Epoch [140/500], Best Val RMSE: 0.01027
#
# Saving model... Epoch [141/500], Best Val RMSE: 0.01027
#
# Saving model... Epoch [142/500], Best Val RMSE: 0.01027
#
# Saving model... Epoch [143/500], Best Val RMSE: 0.01026
#
# Saving model... Epoch [144/500], Best Val RMSE: 0.01026
#
# Saving model... Epoch [145/500], Best Val RMSE: 0.01026
#
# Saving model... Epoch [146/500], Best Val RMSE: 0.01026
#
# Saving model... Epoch [147/500], Best Val RMSE: 0.01026
#
# Epoch   148: reducing learning rate of group 0 to 1.0000e-03.
# Saving model... Epoch [148/500], Best Val RMSE: 0.01026
#
# Epoch   149: reducing learning rate of group 0 to 1.0000e-04.
# Epoch   150: reducing learning rate of group 0 to 1.0000e-05.
# Epoch [198/500], Best Val RMSE: 0.01026
#
# Saving model... Epoch [1/500], Best Val RMSE: 0.02704
#
# Saving model... Epoch [2/500], Best Val RMSE: 0.02650
#
# Saving model... Epoch [3/500], Best Val RMSE: 0.02593
#
# Saving model... Epoch [4/500], Best Val RMSE: 0.02517
#
# Saving model... Epoch [5/500], Best Val RMSE: 0.02416
#
# Saving model... Epoch [6/500], Best Val RMSE: 0.02285
#
# Saving model... Epoch [7/500], Best Val RMSE: 0.02121
#
# Saving model... Epoch [8/500], Best Val RMSE: 0.01931
#
# Saving model... Epoch [9/500], Best Val RMSE: 0.01738
#
# Saving model... Epoch [10/500], Best Val RMSE: 0.01573
#
# Saving model... Epoch [11/500], Best Val RMSE: 0.01456
#
# Saving model... Epoch [12/500], Best Val RMSE: 0.01381
#
# Saving model... Epoch [13/500], Best Val RMSE: 0.01333
#
# Saving model... Epoch [14/500], Best Val RMSE: 0.01299
#
# Saving model... Epoch [15/500], Best Val RMSE: 0.01272
#
# Saving model... Epoch [16/500], Best Val RMSE: 0.01248
#
# Saving model... Epoch [17/500], Best Val RMSE: 0.01227
#
# Saving model... Epoch [18/500], Best Val RMSE: 0.01207
#
# Saving model... Epoch [19/500], Best Val RMSE: 0.01189
#
# Saving model... Epoch [20/500], Best Val RMSE: 0.01173
#
# Saving model... Epoch [21/500], Best Val RMSE: 0.01157
#
# Saving model... Epoch [22/500], Best Val RMSE: 0.01143
#
# Saving model... Epoch [23/500], Best Val RMSE: 0.01130
#
# Saving model... Epoch [24/500], Best Val RMSE: 0.01118
#
# Saving model... Epoch [25/500], Best Val RMSE: 0.01107
#
# Saving model... Epoch [26/500], Best Val RMSE: 0.01097
#
# Saving model... Epoch [27/500], Best Val RMSE: 0.01087
#
# Saving model... Epoch [28/500], Best Val RMSE: 0.01079
#
# Saving model... Epoch [29/500], Best Val RMSE: 0.01071
#
# Saving model... Epoch [30/500], Best Val RMSE: 0.01063
#
# Saving model... Epoch [31/500], Best Val RMSE: 0.01056
#
# Saving model... Epoch [32/500], Best Val RMSE: 0.01049
#
# Saving model... Epoch [33/500], Best Val RMSE: 0.01043
#
# Saving model... Epoch [34/500], Best Val RMSE: 0.01037
#
# Saving model... Epoch [35/500], Best Val RMSE: 0.01032
#
# Saving model... Epoch [36/500], Best Val RMSE: 0.01027
#
# Saving model... Epoch [37/500], Best Val RMSE: 0.01022
#
# Saving model... Epoch [38/500], Best Val RMSE: 0.01017
#
# Saving model... Epoch [39/500], Best Val RMSE: 0.01013
#
# Saving model... Epoch [40/500], Best Val RMSE: 0.01008
#
# Saving model... Epoch [41/500], Best Val RMSE: 0.01005
#
# Saving model... Epoch [42/500], Best Val RMSE: 0.01001
#
# Saving model... Epoch [43/500], Best Val RMSE: 0.00997
#
# Saving model... Epoch [44/500], Best Val RMSE: 0.00994
#
# Saving model... Epoch [45/500], Best Val RMSE: 0.00991
#
# Saving model... Epoch [46/500], Best Val RMSE: 0.00988
#
# Saving model... Epoch [47/500], Best Val RMSE: 0.00985
#
# Saving model... Epoch [48/500], Best Val RMSE: 0.00982
#
# Saving model... Epoch [49/500], Best Val RMSE: 0.00979
#
# Saving model... Epoch [50/500], Best Val RMSE: 0.00976
#
# Saving model... Epoch [51/500], Best Val RMSE: 0.00974
#
# Saving model... Epoch [52/500], Best Val RMSE: 0.00971
#
# Saving model... Epoch [53/500], Best Val RMSE: 0.00969
#
# Saving model... Epoch [54/500], Best Val RMSE: 0.00967
#
# Saving model... Epoch [55/500], Best Val RMSE: 0.00965
#
# Saving model... Epoch [56/500], Best Val RMSE: 0.00963
#
# Saving model... Epoch [57/500], Best Val RMSE: 0.00961
#
# Saving model... Epoch [58/500], Best Val RMSE: 0.00959
#
# Saving model... Epoch [59/500], Best Val RMSE: 0.00957
#
# Saving model... Epoch [60/500], Best Val RMSE: 0.00955
#
# Saving model... Epoch [61/500], Best Val RMSE: 0.00953
#
# Saving model... Epoch [62/500], Best Val RMSE: 0.00952
#
# Saving model... Epoch [63/500], Best Val RMSE: 0.00950
#
# Saving model... Epoch [64/500], Best Val RMSE: 0.00949
#
# Saving model... Epoch [65/500], Best Val RMSE: 0.00947
#
# Saving model... Epoch [66/500], Best Val RMSE: 0.00946
#
# Saving model... Epoch [67/500], Best Val RMSE: 0.00945
#
# Saving model... Epoch [68/500], Best Val RMSE: 0.00943
#
# Saving model... Epoch [69/500], Best Val RMSE: 0.00942
#
# Saving model... Epoch [70/500], Best Val RMSE: 0.00941
#
# Saving model... Epoch [71/500], Best Val RMSE: 0.00939
#
# Saving model... Epoch [72/500], Best Val RMSE: 0.00938
#
# Saving model... Epoch [73/500], Best Val RMSE: 0.00937
#
# Saving model... Epoch [74/500], Best Val RMSE: 0.00936
#
# Saving model... Epoch [75/500], Best Val RMSE: 0.00935
#
# Saving model... Epoch [76/500], Best Val RMSE: 0.00933
#
# Saving model... Epoch [77/500], Best Val RMSE: 0.00932
#
# Saving model... Epoch [78/500], Best Val RMSE: 0.00931
#
# Saving model... Epoch [79/500], Best Val RMSE: 0.00930
#
# Saving model... Epoch [80/500], Best Val RMSE: 0.00929
#
# Saving model... Epoch [81/500], Best Val RMSE: 0.00928
#
# Saving model... Epoch [82/500], Best Val RMSE: 0.00927
#
# Saving model... Epoch [83/500], Best Val RMSE: 0.00926
#
# Saving model... Epoch [84/500], Best Val RMSE: 0.00925
#
# Saving model... Epoch [85/500], Best Val RMSE: 0.00924
#
# Saving model... Epoch [86/500], Best Val RMSE: 0.00923
#
# Saving model... Epoch [87/500], Best Val RMSE: 0.00922
#
# Saving model... Epoch [88/500], Best Val RMSE: 0.00922
#
# Saving model... Epoch [89/500], Best Val RMSE: 0.00921
#
# Saving model... Epoch [90/500], Best Val RMSE: 0.00920
#
# Saving model... Epoch [91/500], Best Val RMSE: 0.00919
#
# Saving model... Epoch [92/500], Best Val RMSE: 0.00918
#
# Saving model... Epoch [93/500], Best Val RMSE: 0.00918
#
# Saving model... Epoch [94/500], Best Val RMSE: 0.00917
#
# Saving model... Epoch [95/500], Best Val RMSE: 0.00916
#
# Saving model... Epoch [96/500], Best Val RMSE: 0.00915
#
# Saving model... Epoch [97/500], Best Val RMSE: 0.00915
#
# Saving model... Epoch [98/500], Best Val RMSE: 0.00914
#
# Saving model... Epoch [99/500], Best Val RMSE: 0.00913
#
# Saving model... Epoch [100/500], Best Val RMSE: 0.00912
#
# Saving model... Epoch [101/500], Best Val RMSE: 0.00912
#
# Saving model... Epoch [102/500], Best Val RMSE: 0.00911
#
# Saving model... Epoch [103/500], Best Val RMSE: 0.00910
#
# Saving model... Epoch [104/500], Best Val RMSE: 0.00910
#
# Saving model... Epoch [105/500], Best Val RMSE: 0.00909
#
# Saving model... Epoch [106/500], Best Val RMSE: 0.00908
#
# Saving model... Epoch [107/500], Best Val RMSE: 0.00908
#
# Saving model... Epoch [108/500], Best Val RMSE: 0.00907
#
# Saving model... Epoch [109/500], Best Val RMSE: 0.00907
#
# Saving model... Epoch [110/500], Best Val RMSE: 0.00906
#
# Saving model... Epoch [111/500], Best Val RMSE: 0.00906
#
# Saving model... Epoch [112/500], Best Val RMSE: 0.00905
#
# Saving model... Epoch [113/500], Best Val RMSE: 0.00905
#
# Saving model... Epoch [114/500], Best Val RMSE: 0.00904
#
# Saving model... Epoch [115/500], Best Val RMSE: 0.00903
#
# Saving model... Epoch [116/500], Best Val RMSE: 0.00903
#
# Saving model... Epoch [117/500], Best Val RMSE: 0.00902
#
# Saving model... Epoch [118/500], Best Val RMSE: 0.00902
#
# Saving model... Epoch [119/500], Best Val RMSE: 0.00901
#
# Saving model... Epoch [120/500], Best Val RMSE: 0.00901
#
# Saving model... Epoch [121/500], Best Val RMSE: 0.00900
#
# Saving model... Epoch [122/500], Best Val RMSE: 0.00900
#
# Saving model... Epoch [123/500], Best Val RMSE: 0.00899
#
# Saving model... Epoch [124/500], Best Val RMSE: 0.00899
#
# Saving model... Epoch [125/500], Best Val RMSE: 0.00898
#
# Epoch   126: reducing learning rate of group 0 to 1.0000e-03.
# Saving model... Epoch [127/500], Best Val RMSE: 0.00894
#
# Saving model... Epoch [128/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [129/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [130/500], Best Val RMSE: 0.00893
#
# Epoch   131: reducing learning rate of group 0 to 1.0000e-04.
# Saving model... Epoch [131/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [132/500], Best Val RMSE: 0.00893
#
# Epoch   133: reducing learning rate of group 0 to 1.0000e-05.
# Saving model... Epoch [133/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [134/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [135/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [136/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [137/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [138/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [139/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [140/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [141/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [142/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [143/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [144/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [145/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [146/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [147/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [148/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [149/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [150/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [151/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [152/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [153/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [154/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [155/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [156/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [157/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [158/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [159/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [160/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [161/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [162/500], Best Val RMSE: 0.00893
#
# Saving model... Epoch [163/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [164/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [165/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [166/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [167/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [168/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [169/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [170/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [171/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [172/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [173/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [174/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [175/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [176/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [177/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [178/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [179/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [180/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [181/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [182/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [183/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [184/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [185/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [186/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [187/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [188/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [189/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [190/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [191/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [192/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [193/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [194/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [195/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [196/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [197/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [198/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [199/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [200/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [201/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [202/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [203/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [204/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [205/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [206/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [207/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [208/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [209/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [210/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [211/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [212/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [213/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [214/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [215/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [216/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [217/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [218/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [219/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [220/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [221/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [222/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [223/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [224/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [225/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [226/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [227/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [228/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [229/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [230/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [231/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [232/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [233/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [234/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [235/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [236/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [237/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [238/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [239/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [240/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [241/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [242/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [243/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [244/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [245/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [246/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [247/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [248/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [249/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [250/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [251/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [252/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [253/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [254/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [255/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [256/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [257/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [258/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [259/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [260/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [261/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [262/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [263/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [264/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [265/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [266/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [267/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [268/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [269/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [270/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [271/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [272/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [273/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [274/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [275/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [276/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [277/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [278/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [279/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [280/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [281/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [282/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [283/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [284/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [285/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [286/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [287/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [288/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [289/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [290/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [291/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [292/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [293/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [294/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [295/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [296/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [297/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [298/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [299/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [300/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [301/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [302/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [303/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [304/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [305/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [306/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [307/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [308/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [309/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [310/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [311/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [312/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [313/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [314/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [315/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [316/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [317/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [318/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [319/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [320/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [321/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [322/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [323/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [324/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [325/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [326/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [327/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [328/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [329/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [330/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [331/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [332/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [333/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [334/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [335/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [336/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [337/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [338/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [339/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [340/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [341/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [342/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [343/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [344/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [345/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [346/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [347/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [348/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [349/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [350/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [351/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [352/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [353/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [354/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [355/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [356/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [357/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [358/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [359/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [360/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [361/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [362/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [363/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [364/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [365/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [366/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [367/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [368/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [369/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [370/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [371/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [372/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [373/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [374/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [375/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [376/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [377/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [378/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [379/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [380/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [381/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [382/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [383/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [384/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [385/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [386/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [387/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [388/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [389/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [390/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [391/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [392/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [393/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [394/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [395/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [396/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [397/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [398/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [399/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [400/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [401/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [402/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [403/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [404/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [405/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [406/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [407/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [408/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [409/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [410/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [411/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [412/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [413/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [414/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [415/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [416/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [417/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [418/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [419/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [420/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [421/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [422/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [423/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [424/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [425/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [426/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [427/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [428/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [429/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [430/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [431/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [432/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [433/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [434/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [435/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [436/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [437/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [438/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [439/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [440/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [441/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [442/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [443/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [444/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [445/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [446/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [447/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [448/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [449/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [450/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [451/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [452/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [453/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [454/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [455/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [456/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [457/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [458/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [459/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [460/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [461/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [462/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [463/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [464/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [465/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [466/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [467/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [468/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [469/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [470/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [471/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [472/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [473/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [474/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [475/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [476/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [477/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [478/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [479/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [480/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [481/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [482/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [483/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [484/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [485/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [486/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [487/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [488/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [489/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [490/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [491/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [492/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [493/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [494/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [495/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [496/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [497/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [498/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [499/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [500/500], Best Val RMSE: 0.00892
#
# Saving model... Epoch [1/500], Best Val RMSE: 0.02376
#
# Saving model... Epoch [2/500], Best Val RMSE: 0.02214
#
# Saving model... Epoch [3/500], Best Val RMSE: 0.02017
#
# Saving model... Epoch [4/500], Best Val RMSE: 0.01813
#
# Saving model... Epoch [5/500], Best Val RMSE: 0.01632
#
# Saving model... Epoch [6/500], Best Val RMSE: 0.01494
#
# Saving model... Epoch [7/500], Best Val RMSE: 0.01403
#
# Saving model... Epoch [8/500], Best Val RMSE: 0.01343
#
# Saving model... Epoch [9/500], Best Val RMSE: 0.01298
#
# Saving model... Epoch [10/500], Best Val RMSE: 0.01262
#
# Saving model... Epoch [11/500], Best Val RMSE: 0.01229
#
# Saving model... Epoch [12/500], Best Val RMSE: 0.01198
#
# Saving model... Epoch [13/500], Best Val RMSE: 0.01168
#
# Saving model... Epoch [14/500], Best Val RMSE: 0.01140
#
# Saving model... Epoch [15/500], Best Val RMSE: 0.01115
#
# Saving model... Epoch [16/500], Best Val RMSE: 0.01092
#
# Saving model... Epoch [17/500], Best Val RMSE: 0.01071
#
# Saving model... Epoch [18/500], Best Val RMSE: 0.01052
#
# Saving model... Epoch [19/500], Best Val RMSE: 0.01035
#
# Saving model... Epoch [20/500], Best Val RMSE: 0.01019
#
# Saving model... Epoch [21/500], Best Val RMSE: 0.01005
#
# Saving model... Epoch [22/500], Best Val RMSE: 0.00992
#
# Saving model... Epoch [23/500], Best Val RMSE: 0.00981
#
# Saving model... Epoch [24/500], Best Val RMSE: 0.00970
#
# Saving model... Epoch [25/500], Best Val RMSE: 0.00961
#
# Saving model... Epoch [26/500], Best Val RMSE: 0.00952
#
# Saving model... Epoch [27/500], Best Val RMSE: 0.00945
#
# Saving model... Epoch [28/500], Best Val RMSE: 0.00937
#
# Saving model... Epoch [29/500], Best Val RMSE: 0.00931
#
# Saving model... Epoch [30/500], Best Val RMSE: 0.00925
#
# Saving model... Epoch [31/500], Best Val RMSE: 0.00919
#
# Saving model... Epoch [32/500], Best Val RMSE: 0.00914
#
# Saving model... Epoch [33/500], Best Val RMSE: 0.00909
#
# Saving model... Epoch [34/500], Best Val RMSE: 0.00905
#
# Saving model... Epoch [35/500], Best Val RMSE: 0.00901
#
# Saving model... Epoch [36/500], Best Val RMSE: 0.00897
#
# Saving model... Epoch [37/500], Best Val RMSE: 0.00894
#
# Saving model... Epoch [38/500], Best Val RMSE: 0.00890
#
# Saving model... Epoch [39/500], Best Val RMSE: 0.00887
#
# Saving model... Epoch [40/500], Best Val RMSE: 0.00885
#
# Saving model... Epoch [41/500], Best Val RMSE: 0.00882
#
# Saving model... Epoch [42/500], Best Val RMSE: 0.00879
#
# Saving model... Epoch [43/500], Best Val RMSE: 0.00877
#
# Saving model... Epoch [44/500], Best Val RMSE: 0.00874
#
# Saving model... Epoch [45/500], Best Val RMSE: 0.00872
#
# Saving model... Epoch [46/500], Best Val RMSE: 0.00870
#
# Saving model... Epoch [47/500], Best Val RMSE: 0.00868
#
# Saving model... Epoch [48/500], Best Val RMSE: 0.00866
#
# Saving model... Epoch [49/500], Best Val RMSE: 0.00864
#
# Saving model... Epoch [50/500], Best Val RMSE: 0.00862
#
# Saving model... Epoch [51/500], Best Val RMSE: 0.00860
#
# Saving model... Epoch [52/500], Best Val RMSE: 0.00858
#
# Saving model... Epoch [53/500], Best Val RMSE: 0.00856
#
# Saving model... Epoch [54/500], Best Val RMSE: 0.00855
#
# Saving model... Epoch [55/500], Best Val RMSE: 0.00853
#
# Saving model... Epoch [56/500], Best Val RMSE: 0.00852
#
# Saving model... Epoch [57/500], Best Val RMSE: 0.00850
#
# Saving model... Epoch [58/500], Best Val RMSE: 0.00849
#
# Saving model... Epoch [59/500], Best Val RMSE: 0.00847
#
# Saving model... Epoch [60/500], Best Val RMSE: 0.00846
#
# Saving model... Epoch [61/500], Best Val RMSE: 0.00845
#
# Saving model... Epoch [62/500], Best Val RMSE: 0.00844
#
# Saving model... Epoch [63/500], Best Val RMSE: 0.00842
#
# Saving model... Epoch [64/500], Best Val RMSE: 0.00841
#
# Saving model... Epoch [65/500], Best Val RMSE: 0.00840
#
# Saving model... Epoch [66/500], Best Val RMSE: 0.00839
#
# Saving model... Epoch [67/500], Best Val RMSE: 0.00838
#
# Saving model... Epoch [68/500], Best Val RMSE: 0.00837
#
# Saving model... Epoch [69/500], Best Val RMSE: 0.00836
#
# Saving model... Epoch [70/500], Best Val RMSE: 0.00835
#
# Saving model... Epoch [71/500], Best Val RMSE: 0.00834
#
# Saving model... Epoch [72/500], Best Val RMSE: 0.00833
#
# Saving model... Epoch [73/500], Best Val RMSE: 0.00832
#
# Saving model... Epoch [74/500], Best Val RMSE: 0.00832
#
# Saving model... Epoch [75/500], Best Val RMSE: 0.00831
#
# Saving model... Epoch [76/500], Best Val RMSE: 0.00830
#
# Saving model... Epoch [77/500], Best Val RMSE: 0.00829
#
# Saving model... Epoch [78/500], Best Val RMSE: 0.00828
#
# Saving model... Epoch [79/500], Best Val RMSE: 0.00828
#
# Saving model... Epoch [80/500], Best Val RMSE: 0.00827
#
# Saving model... Epoch [81/500], Best Val RMSE: 0.00826
#
# Saving model... Epoch [82/500], Best Val RMSE: 0.00825
#
# Saving model... Epoch [83/500], Best Val RMSE: 0.00825
#
# Saving model... Epoch [84/500], Best Val RMSE: 0.00824
#
# Saving model... Epoch [85/500], Best Val RMSE: 0.00823
#
# Saving model... Epoch [86/500], Best Val RMSE: 0.00823
#
# Saving model... Epoch [87/500], Best Val RMSE: 0.00822
#
# Saving model... Epoch [88/500], Best Val RMSE: 0.00821
#
# Saving model... Epoch [89/500], Best Val RMSE: 0.00821
#
# Saving model... Epoch [90/500], Best Val RMSE: 0.00820
#
# Saving model... Epoch [91/500], Best Val RMSE: 0.00820
#
# Saving model... Epoch [92/500], Best Val RMSE: 0.00819
#
# Saving model... Epoch [93/500], Best Val RMSE: 0.00819
#
# Saving model... Epoch [94/500], Best Val RMSE: 0.00818
#
# Saving model... Epoch [95/500], Best Val RMSE: 0.00818
#
# Saving model... Epoch [96/500], Best Val RMSE: 0.00817
#
# Saving model... Epoch [97/500], Best Val RMSE: 0.00817
#
# Saving model... Epoch [98/500], Best Val RMSE: 0.00816
#
# Saving model... Epoch [99/500], Best Val RMSE: 0.00816
#
# Saving model... Epoch [100/500], Best Val RMSE: 0.00815
#
# Saving model... Epoch [101/500], Best Val RMSE: 0.00815
#
# Saving model... Epoch [102/500], Best Val RMSE: 0.00814
#
# Saving model... Epoch [103/500], Best Val RMSE: 0.00814
#
# Saving model... Epoch [104/500], Best Val RMSE: 0.00814
#
# Saving model... Epoch [105/500], Best Val RMSE: 0.00813
#
# Saving model... Epoch [106/500], Best Val RMSE: 0.00813
#
# Saving model... Epoch [107/500], Best Val RMSE: 0.00813
#
# Saving model... Epoch [108/500], Best Val RMSE: 0.00812
#
# Saving model... Epoch [109/500], Best Val RMSE: 0.00812
#
# Saving model... Epoch [110/500], Best Val RMSE: 0.00811
#
# Saving model... Epoch [111/500], Best Val RMSE: 0.00811
#
# Saving model... Epoch [112/500], Best Val RMSE: 0.00811
#
# Saving model... Epoch [113/500], Best Val RMSE: 0.00810
#
# Saving model... Epoch [114/500], Best Val RMSE: 0.00810
#
# Saving model... Epoch [115/500], Best Val RMSE: 0.00810
#
# Saving model... Epoch [116/500], Best Val RMSE: 0.00809
#
# Saving model... Epoch [117/500], Best Val RMSE: 0.00809
#
# Saving model... Epoch [118/500], Best Val RMSE: 0.00809
#
# Saving model... Epoch [119/500], Best Val RMSE: 0.00808
#
# Saving model... Epoch [120/500], Best Val RMSE: 0.00808
#
# Saving model... Epoch [121/500], Best Val RMSE: 0.00808
#
# Saving model... Epoch [122/500], Best Val RMSE: 0.00807
#
# Saving model... Epoch [123/500], Best Val RMSE: 0.00807
#
# Saving model... Epoch [124/500], Best Val RMSE: 0.00807
#
# Saving model... Epoch [125/500], Best Val RMSE: 0.00806
#
# Saving model... Epoch [126/500], Best Val RMSE: 0.00806
#
# Saving model... Epoch [127/500], Best Val RMSE: 0.00806
#
# Saving model... Epoch [128/500], Best Val RMSE: 0.00806
#
# Saving model... Epoch [129/500], Best Val RMSE: 0.00805
#
# Saving model... Epoch [130/500], Best Val RMSE: 0.00805
#
# Saving model... Epoch [131/500], Best Val RMSE: 0.00805
#
# Saving model... Epoch [132/500], Best Val RMSE: 0.00805
#
# Saving model... Epoch [133/500], Best Val RMSE: 0.00804
#
# Saving model... Epoch [134/500], Best Val RMSE: 0.00804
#
# Saving model... Epoch [135/500], Best Val RMSE: 0.00804
#
# Saving model... Epoch [136/500], Best Val RMSE: 0.00804
#
# Saving model... Epoch [137/500], Best Val RMSE: 0.00803
#
# Saving model... Epoch [138/500], Best Val RMSE: 0.00803
#
# Saving model... Epoch [139/500], Best Val RMSE: 0.00803
#
# Saving model... Epoch [140/500], Best Val RMSE: 0.00803
#
# Saving model... Epoch [141/500], Best Val RMSE: 0.00802
#
# Saving model... Epoch [142/500], Best Val RMSE: 0.00802
#
# Saving model... Epoch [143/500], Best Val RMSE: 0.00802
#
# Saving model... Epoch [144/500], Best Val RMSE: 0.00802
#
# Saving model... Epoch [145/500], Best Val RMSE: 0.00801
#
# Saving model... Epoch [146/500], Best Val RMSE: 0.00801
#
# Saving model... Epoch [147/500], Best Val RMSE: 0.00801
#
# Saving model... Epoch [148/500], Best Val RMSE: 0.00801
#
# Saving model... Epoch [149/500], Best Val RMSE: 0.00800
#
# Saving model... Epoch [150/500], Best Val RMSE: 0.00800
#
# Saving model... Epoch [151/500], Best Val RMSE: 0.00800
#
# Saving model... Epoch [152/500], Best Val RMSE: 0.00800
#
# Saving model... Epoch [153/500], Best Val RMSE: 0.00800
#
# Saving model... Epoch [154/500], Best Val RMSE: 0.00799
#
# Saving model... Epoch [155/500], Best Val RMSE: 0.00799
#
# Saving model... Epoch [156/500], Best Val RMSE: 0.00799
#
# Saving model... Epoch [157/500], Best Val RMSE: 0.00799
#
# Saving model... Epoch [158/500], Best Val RMSE: 0.00799
#
# Saving model... Epoch [159/500], Best Val RMSE: 0.00798
#
# Saving model... Epoch [160/500], Best Val RMSE: 0.00798
#
# Saving model... Epoch [161/500], Best Val RMSE: 0.00798
#
# Saving model... Epoch [162/500], Best Val RMSE: 0.00798
#
# Saving model... Epoch [163/500], Best Val RMSE: 0.00798
#
# Saving model... Epoch [164/500], Best Val RMSE: 0.00798
#
# Saving model... Epoch [165/500], Best Val RMSE: 0.00798
#
# Saving model... Epoch [166/500], Best Val RMSE: 0.00797
#
# Saving model... Epoch [167/500], Best Val RMSE: 0.00797
#
# Saving model... Epoch [168/500], Best Val RMSE: 0.00797
#
# Saving model... Epoch [169/500], Best Val RMSE: 0.00797
#
# Saving model... Epoch [170/500], Best Val RMSE: 0.00797
#
# Saving model... Epoch [171/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [172/500], Best Val RMSE: 0.00796
#
# Epoch   173: reducing learning rate of group 0 to 1.0000e-03.
# Saving model... Epoch [173/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [174/500], Best Val RMSE: 0.00796
#
# Epoch   175: reducing learning rate of group 0 to 1.0000e-04.
# Saving model... Epoch [175/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [176/500], Best Val RMSE: 0.00796
#
# Epoch   177: reducing learning rate of group 0 to 1.0000e-05.
# Saving model... Epoch [177/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [178/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [179/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [180/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [181/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [182/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [183/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [184/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [185/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [186/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [187/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [188/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [189/500], Best Val RMSE: 0.00796
#
# Saving model... Epoch [190/500], Best Val RMSE: 0.00796
#
# ...
#
# Saving model... Epoch [223/500], Best Val RMSE: 0.00731
#
# Epoch   224: reducing learning rate of group 0 to 1.0000e-04.
# Saving model... Epoch [224/500], Best Val RMSE: 0.00730
#
# Saving model... Epoch [225/500], Best Val RMSE: 0.00730
#
# Saving model... Epoch [226/500], Best Val RMSE: 0.00730
#
# Saving model... Epoch [227/500], Best Val RMSE: 0.00730
#
# Saving model... Epoch [228/500], Best Val RMSE: 0.00730
#
# Saving model... Epoch [229/500], Best Val RMSE: 0.00730
#
# Saving model... Epoch [230/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [231/500], Best Val RMSE: 0.00729
#
# Epoch   232: reducing learning rate of group 0 to 1.0000e-05.
# Saving model... Epoch [232/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [233/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [234/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [235/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [236/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [237/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [238/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [239/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [240/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [241/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [242/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [243/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [244/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [245/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [246/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [247/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [248/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [249/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [250/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [251/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [252/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [253/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [254/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [255/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [256/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [257/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [258/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [259/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [260/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [261/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [262/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [263/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [264/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [265/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [266/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [267/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [268/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [269/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [270/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [271/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [272/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [273/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [274/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [275/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [276/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [277/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [278/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [279/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [280/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [281/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [282/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [283/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [284/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [285/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [286/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [287/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [288/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [289/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [290/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [291/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [292/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [293/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [294/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [295/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [296/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [297/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [298/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [299/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [300/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [301/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [302/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [303/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [304/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [305/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [306/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [307/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [308/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [309/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [310/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [311/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [312/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [313/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [314/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [315/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [316/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [317/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [318/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [319/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [320/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [321/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [322/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [323/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [324/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [325/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [326/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [327/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [328/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [329/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [330/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [331/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [332/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [333/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [334/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [335/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [336/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [337/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [338/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [339/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [340/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [341/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [342/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [343/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [344/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [345/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [346/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [347/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [348/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [349/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [350/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [351/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [352/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [353/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [354/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [355/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [356/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [357/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [358/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [359/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [360/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [361/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [362/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [363/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [364/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [365/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [366/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [367/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [368/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [369/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [370/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [371/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [372/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [373/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [374/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [375/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [376/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [377/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [378/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [379/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [380/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [381/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [382/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [383/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [384/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [385/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [386/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [387/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [388/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [389/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [390/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [391/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [392/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [393/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [394/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [395/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [396/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [397/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [398/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [399/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [400/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [401/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [402/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [403/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [404/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [405/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [406/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [407/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [408/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [409/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [410/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [411/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [412/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [413/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [414/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [415/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [416/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [417/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [418/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [419/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [420/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [421/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [422/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [423/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [424/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [425/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [426/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [427/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [428/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [429/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [430/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [431/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [432/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [433/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [434/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [435/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [436/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [437/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [438/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [439/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [440/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [441/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [442/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [443/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [444/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [445/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [446/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [447/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [448/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [449/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [450/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [451/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [452/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [453/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [454/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [455/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [456/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [457/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [458/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [459/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [460/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [461/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [462/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [463/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [464/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [465/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [466/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [467/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [468/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [469/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [470/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [471/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [472/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [473/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [474/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [475/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [476/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [477/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [478/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [479/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [480/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [481/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [482/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [483/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [484/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [485/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [486/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [487/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [488/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [489/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [490/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [491/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [492/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [493/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [494/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [495/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [496/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [497/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [498/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [499/500], Best Val RMSE: 0.00729
#
# Saving model... Epoch [500/500], Best Val RMSE: 0.00729

# %%
# calculate performance
rmse = np.linalg.norm(y - oof)/len(y)
R2 = r2_score(y, oof)

plt.figure(figsize=(9, 6))

plt.scatter(oof, y, alpha=.6, label="NN, RMSE: {:.5f}, R2: {:.5f}".format(rmse, R2))
plt.xlabel("Predicted house price", fontsize=16)
plt.ylabel("True house price", fontsize=16)

plt.legend(fontsize=14)
plt.title("Neural network", fontsize=18)
plt.savefig("Figures/NeuralNetwork.png", dpi=150)
plt.show()
